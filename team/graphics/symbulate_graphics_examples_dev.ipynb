# %%
pip install git+https://github.com/calpoly-symbulate/symbulate.git@dev
# Out:
# Collecting git+https://github.com/calpoly-symbulate/symbulate.git@dev
#   Cloning https://github.com/calpoly-symbulate/symbulate.git (to revision dev) to /tmp/pip-req-build-espp0zgc
#   Running command git clone --filter=blob:none --quiet https://github.com/calpoly-symbulate/symbulate.git /tmp/pip-req-build-espp0zgc
#   Running command git checkout -b dev --track origin/dev
#   Switched to a new branch 'dev'
#   Branch 'dev' set up to track remote branch 'dev' from 'origin'.
#   Resolved https://github.com/calpoly-symbulate/symbulate.git to commit 2901e8f99cd7bc33b82582f1910ccf35912dde8a
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from symbulate==0.5.5) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from symbulate==0.5.5) (1.16.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from symbulate==0.5.5) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->symbulate==0.5.5) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->symbulate==0.5.5) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->symbulate==0.5.5) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->symbulate==0.5.5) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->symbulate==0.5.5) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->symbulate==0.5.5) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->symbulate==0.5.5) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->symbulate==0.5.5) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->symbulate==0.5.5) (1.17.0)

# %%
from symbulate import *

# %% [markdown]
# ## Discrete to continuous needs to be stricter

# %%
RV(Poisson(15)).sim(10000).plot()
# Out:
# Currently Showing: Impulse Plot (Default)
# Alternative Plots: Histogram (type = "hist"), Dot Plot (type = "dotplot"), ECDF Plot (type = "ecdf")

# %%
RV(Poisson(15)).sim(10000).plot()

# %% [markdown]
# ## Axis labels in 2d plots with at least one discrete

# %%
RV(Poisson(15) * Poisson(15)).sim(10000).plot()

# %%
RV(Poisson(200) * Normal()).sim(40).plot()

# %% [markdown]
# ## Histogram bins

# %%
RV(F(5,4)).sim(10000).plot()

# %%
RV(F(5,4)).sim(10000).plot()
F(5, 4).plot()

# %% [markdown]
# ## Dots with high stacks - probably ok. Though look at x-axis on this example?

# %%
RV(Bernoulli(0.05)).sim(99).plot()

# %% [markdown]
# ## Fix marginal

# %%
RV(Poisson(5) * Poisson(10)).sim(10000).plot(type=["tile", "marginal"])

# %%
RV(Normal() * Normal()).sim(10000).plot(type=["hist", "marginal"])

# %%
RV(Normal() * Normal()).sim(10000).plot(type=["density", "marginal"])

# %% [markdown]
# ## Rethink lollipop impulse or dots in Distribution.plot()

# %%
Poisson(10).plot()
RV(Poisson(10)).sim(10000).plot()

# %% [markdown]
# ## Distribution.plot() axis limits (and plot style)

# %%
Poisson(100).plot()

# %%
RV(Poisson(100)).sim(10000).plot()
Poisson(100).plot()

# %%
Binomial(1000, 0.5).plot()

# %%
RV(Binomial(1000, 0.5)).sim(10000).plot()
Binomial(1000, 0.5).plot()

# %% [markdown]
# ## Color cycling

# %%
RV(Normal()).sim(500).plot(["rug", "hist", "density"])

# %%
RV(Normal()).sim(500).plot("hist")
RV(Normal()).sim(500).plot("rug")
RV(Normal()).sim(500).plot("density")

# %% [markdown]
# ## Random Processes - a whole separate task

# %%
X = BrownianMotion()

X.sim(1).plot()

# %%
X.sim(100).plot()

# %%
X = MarkovChain([[0, 0.8, 0.2], [0.3, 0.4, 0.3], [0.6, 0.2, 0.2]], [1, 0, 0])

X.sim(1).plot()

# %%
X.sim(5).plot()

# %%
X.sim(100).plot()

# %%
X = ContinuousTimeMarkovChain([[-2, 1.6, 0.4], [0.3, -0.6, 0.3], [0.6, 0.2, -0.8]], [1, 0, 0])

X.sim(1).plot()

# %%
X.sim(5).plot()

# %%
X.sim(100).plot()
