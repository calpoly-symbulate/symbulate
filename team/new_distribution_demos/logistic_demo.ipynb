# %% [markdown]
# # Logistic Distribution
#
# `Logistic(loc, scale)` is a continuous distribution that underlies logistic regression.

# %%
from symbulate import *

# %% [markdown]
# ## Define a Logistic distribution and draw a value

# %%
X = Logistic(loc=0, scale=1)
X.draw()
# Out:
# 3.4322651221504037

# %% [markdown]
# ## Theoretical mean, variance, and standard deviation
#
# The mean equals `loc`; the standard deviation is `scale * pi / sqrt(3)`.

# %%
X.mean(), X.var(), X.sd()
# Out:
# (np.float64(0.0),
#  np.float64(3.289868133696453),
#  np.float64(1.8137993642342178))

# %% [markdown]
# ## Assigning and simulating a random variable

# %%
L = RV(X)
L.sim(10000)
# Out:
# Index Result
# 0     -1.916427407594879
# 1     -0.3327022284658393
# 2     2.1086369044240696
# 3     -0.49265459573055004
# 4     -0.22138533649593992
# 5     -1.7758099388357012
# 6     -0.08055417164646206
# 7     -0.7108880736481785
# 8     1.3142937546311757
# ....  ...................
# 9999  -1.3121463911627884

# %% [markdown]
# ## Plot the pdf
#
# Centered at `loc`.

# %%
X.plot()

# %% [markdown]
# ## Plot the CDF
#
# This is the sigmoid function used in logistic regression.

# %%
X.plot(cdf=True)

# %% [markdown]
# ## Scale parameter changes the spread

# %%
for s in [0.5, 1, 2, 4]:
    Logistic(loc=0, scale=s).plot()
