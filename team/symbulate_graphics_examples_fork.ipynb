# %%
pip install git+https://github.com/kevindavisross/symbulate
# Out:
# ...
#   Cloning https://github.com/kevindavisross/symbulate to /tmp/pip-req-build-4xpwpisl
#   Running command git clone --filter=blob:none --quiet https://github.com/kevindavisross/symbulate /tmp/pip-req-build-4xpwpisl
#   Resolved https://github.com/kevindavisross/symbulate to commit 7008895cc885d09560bbe3ae7f7cd8eb5ec7d5f3
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for symbulate: filename=symbulate-0.5.5-py3-none-any.whl size=43509 sha256=223eb844c50fb2379772cee03482cc0be059eb92eba0c774fe8942b5f6d77c5a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-agu7ixun/wheels/c1/94/24/dea75e453e4515e128fb89da658f4782b9e6ae2534dce58ca4
# Successfully built symbulate
# ...

# %%
from symbulate import *

# %%
RV(Poisson(15)).sim(10000).plot()

# %%
Normal().plot()

# %%
Normal().plot(cdf=True)

# %%
Poisson(4).plot()

# %%
Poisson(4).plot(cdf=True)

# %%
Normal().plot().shade(lt = 1)

# %%
X = BrownianMotion()

X.sim(1).plot()

# %%
X.sim(100).plot()

# %%
X = MarkovChain([[0, 0.8, 0.2], [0.3, 0.4, 0.3], [0.6, 0.2, 0.2]], [1, 0, 0])

X.sim(1).plot()

# %%
X.sim(5).plot()

# %%
X.sim(100).plot()
