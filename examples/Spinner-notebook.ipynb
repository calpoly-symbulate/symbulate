# %%
import sys
sys.path.insert(0, r"c:\Users\agw07\Documents\calpoly-symbulate")
from symbulate import *

# %%
Binomial(10, 0.3).spinner()

# %%
Binomial(10, 0.3).spinner(mode='equal')

# %%
Normal(0, 1).spinner()

# %%
Normal(0, 1).spinner(mode='equal')

# %%
Poisson(4).spinner()

# %%
Geometric(p=0.4).spinner()

# %%
Exponential(rate=2).spinner()
