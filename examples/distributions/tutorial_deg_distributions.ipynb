# %% [markdown]
# # Degenerate Distribution Examples
#
# A **degenerate distribution** is one where a boundary parameter value makes the outcome deterministic — every draw returns the same value. These cases now work as expected in symbulate instead of raising errors or returning wrong results.

# %%
from symbulate import *

# %% [markdown]
# ---
# ## Poisson
#
# `Poisson(lam=0)` — zero average events means the count is always 0.

# %%
X = RV(Poisson(lam=0))
X.sim(5)
# Out:
# Index Result
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0

# %% [markdown]
# ---
# ## Bernoulli
#
# `Bernoulli(p=0)` — impossible event, always 0.

# %%
X = RV(Bernoulli(p=0))
X.sim(5)
# Out:
# Index Result
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0

# %% [markdown]
# `Bernoulli(p=1)` — certain event, always 1.

# %%
X = RV(Bernoulli(p=1))
X.sim(5)
# Out:
# Index Result
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1

# %% [markdown]
# ---
# ## Binomial
#
# `Binomial(n=10, p=0)` — zero probability of success, always 0.

# %%
X = RV(Binomial(n=10, p=0))
X.sim(5)
# Out:
# Index Result
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0

# %% [markdown]
# `Binomial(n=10, p=1)` — certain success every trial, always n.

# %%
X = RV(Binomial(n=10, p=1))
X.sim(5)
# Out:
# Index Result
# 0     10
# 1     10
# 2     10
# 3     10
# 4     10

# %% [markdown]
# `Binomial(n=0, p=0.5)` — zero trials, always 0.

# %%
X = RV(Binomial(n=0, p=0.5))
X.sim(5)
# Out:
# Index Result
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0

# %% [markdown]
# ---
# ## Geometric
#
# `Geometric(p=1)` — success on the very first trial, always 1.

# %%
X = RV(Geometric(p=1))
X.sim(5)
# Out:
# c:\Users\nicol\anaconda3\Lib\site-packages\scipy\stats\_discrete_distns.py:563: RuntimeWarning: divide by zero encountered in log1p
#   vals = ceil(log1p(-q) / log1p(-p))
# c:\Users\nicol\anaconda3\Lib\site-packages\scipy\stats\_discrete_distns.py:553: RuntimeWarning: divide by zero encountered in log1p
#   return -expm1(log1p(-p)*k)
# Index Result
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1

# %% [markdown]
# ---
# ## NegativeBinomial / Pascal
#
# `NegativeBinomial(r=10, p=1)` — every trial succeeds, so exactly r trials needed, always r.

# %%
X = RV(NegativeBinomial(r=10, p=1))
X.sim(5)
# Out:
# Index Result
# 0     10
# 1     10
# 2     10
# 3     10
# 4     10

# %% [markdown]
# `Pascal(r=10, p=1.0)` — every trial is a success, so 0 failures before r successes, always 0.

# %%
X = RV(Pascal(r=10, p=1.0))
X.sim(5)
# Out:
# Index Result
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0

# %% [markdown]
# ---
# ## DiscreteUniform
#
# `DiscreteUniform(a, b)` with `a == b` — only one possible value.

# %%
X = RV(DiscreteUniform(3, 3))
X.sim(5)
# Out:
# Index Result
# 0     3
# 1     3
# 2     3
# 3     3
# 4     3

# %% [markdown]
# ---
# ## LogNormal
#
# `LogNormal(mu=0, sigma=0)` — zero spread means the value is always `exp(mu)`.

# %%
X = RV(LogNormal(mu=0, sigma=0))
X.sim(5)  # exp(0) = 1
# Out:
# Index Result
# 0     1.0
# 1     1.0
# 2     1.0
# 3     1.0
# 4     1.0

# %%
X = RV(LogNormal(mu=1, sigma=0))
X.sim(5)  # exp(1) ≈ 2.718
# Out:
# Index Result
# 0     2.718281828459045
# 1     2.718281828459045
# 2     2.718281828459045
# 3     2.718281828459045
# 4     2.718281828459045
