# %% [markdown]
# # Zipf Distribution
#
# `Zipf(shape, n)` is a discrete distribution on the ranks `1, 2, ..., n`, where rank `k` has probability proportional to `1 / k ** shape`. A larger `shape` puts more probability on the first few ranks; `shape = 0` makes every rank equally likely. The support is finite: a `Zipf(shape, n)` never produces a value above `n`.

# %%
from symbulate import *

# %% [markdown]
# ## Draw a value from a Zipf distribution

# %%
Zipf(shape=1.2, n=10).draw()
# Out:
# 4

# %% [markdown]
# ## Theoretical mean, variance, and standard deviation
#
# All three are always finite, since there are only `n` possible values.

# %%
Zipf(shape=1.2, n=10).mean(), Zipf(shape=1.2, n=10).var(), Zipf(shape=1.2, n=10).sd()
# Out:
# (np.float64(3.026070014612279),
#  np.float64(6.293660525340199),
#  np.float64(2.5087169081704292))

# %% [markdown]
# ## The pmf
#
# The probabilities over `1, ..., n` add to 1, and anything above `n` is exactly 0.

# %%
Zipf(shape=1.2, n=10).pmf(1), Zipf(shape=1.2, n=10).pmf(10), Zipf(shape=1.2, n=10).pmf(11)
# Out:
# (np.float64(0.4052334497650483),
#  np.float64(0.02556850213583027),
#  np.float64(0.0))

# %% [markdown]
# ## Assign and simulate a random variable

# %%
X = RV(Zipf(shape=1.2, n=10))
X.sim(10000)
# Out:
# Simulating... [█████████████████████████░░░░░] 8635/10000 (86%)
# Simulating... [██████████████████████████░░░░] 8700/10000 (87%)
# Simulating... [██████████████████████████░░░░] 8800/10000 (88%)
# Simulating... [██████████████████████████░░░░] 8900/10000 (89%)
# Simulating... [███████████████████████████░░░] 9000/10000 (90%)
# Simulating... [███████████████████████████░░░] 9100/10000 (91%)
# Simulating... [███████████████████████████░░░] 9200/10000 (92%)
# Simulating... [███████████████████████████░░░] 9300/10000 (93%)
# Simulating... [████████████████████████████░░] 9400/10000 (94%)
# Simulating... [████████████████████████████░░] 9500/10000 (95%)
# Simulating... [████████████████████████████░░] 9600/10000 (96%)
# Simulating... [█████████████████████████████░] 9700/10000 (97%)
# Simulating... [█████████████████████████████░] 9800/10000 (98%)
# Simulating... [█████████████████████████████░] 9900/10000 (99%)
# Simulating... [██████████████████████████████] 10000/10000 (100%)
# ...

# %% [markdown]
# ## Plot the pmf

# %%
Zipf(shape=1.2, n=10).plot()

# %% [markdown]
# ## Plot the CDF

# %%
Zipf(shape=1.2, n=10).plot(cdf=True)

# %% [markdown]
# ## Shape parameter changes the concentration
#
# A larger `shape` piles probability onto the first few ranks and thins the tail; `shape = 0` is flat.

# %%
for shape in [0, 0.5, 1, 2]:
    Zipf(shape=shape, n=10).plot()

# %% [markdown]
# ## Zipf vs. Zeta: finite vs. infinite support
#
# SciPy's naming is a trap. `scipy.stats.zipfian(a, n)` is the finite-support Zipf, which is what Symbulate's `Zipf` wraps; `scipy.stats.zipf(a)` is the *zeta* distribution, supported on `1, 2, 3, ...` with no upper limit. Symbulate has no `Zeta` yet, so the cells below call SciPy for the zeta side.

# %%
from scipy.stats import zipf as zeta   # SciPy's "zipf" is really the zeta distribution

Zipf(shape=2, n=10).pmf(11), zeta.pmf(11, 2)   # above n: impossible vs. still possible
# Out:
# (np.float64(0.0), np.float64(0.005024190924413443))

# %% [markdown]
# Growing `n` with `shape > 1` turns a Zipf into a zeta. For `shape <= 1` the infinite sum diverges, so the zeta does not exist and only the finite version does.

# %%
Zipf(shape=2, n=10).pmf(1), Zipf(shape=2, n=100000).pmf(1), zeta.pmf(1, 2), zeta.pmf(1, 0.8)
# Out:
# (np.float64(0.6452579827864142),
#  np.float64(0.6079307976116269),
#  np.float64(0.6079271018540265),
#  np.float64(nan))

# %% [markdown]
# ## Relationship: chopping a zeta off at `n` gives a Zipf
#
# Keep only the zeta values at or below `n` and what survives is exactly `Zipf(shape, n)`. Requires `shape > 1`, so the zeta exists.

# %%
Z = RV(ProbabilitySpace(lambda: int(zeta.rvs(1.5))))
Z.sim(20000).filter(lambda k: k <= 10).plot()
Zipf(shape=1.5, n=10).plot()
# Out:
# Currently Showing: Impulse Plot (Default)
# Alternative Plots: Histogram (type = "hist"), Dot Plot (type = "dotplot"), ECDF Plot (type = "ecdf")

# %% [markdown]
# ## Relationship: `shape = 0` is a discrete uniform
#
# With `shape = 0` every rank is equally likely, so `Zipf(shape=0, n)` is exactly `DiscreteUniform(1, n)`.

# %%
U = RV(DiscreteUniform(a=1, b=8))
U.sim(10000).plot()
Zipf(shape=0, n=8).plot()

# %% [markdown]
# ## Relationship: a `BoxModel` with power-law weights
#
# A Zipf is a weighted draw from `1, ..., n` with weight `1 / k ** shape` on rank `k`, normalized to add to 1.

# %%
weights = [k**-1.3 for k in range(1, 9)]
B = RV(BoxModel(list(range(1, 9)), probs=[w / sum(weights) for w in weights]))
B.sim(10000).plot()
Zipf(shape=1.3, n=8).plot()

# %% [markdown]
# ## Relationship: with two ranks, a Zipf is a shifted Bernoulli
#
# `Zipf(shape, 2)` is `1 + Bernoulli(p)`, where `p = 2 ** -shape / (1 + 2 ** -shape)` is the chance of rank 2.

# %%
Y = RV(Bernoulli(2**-1.4 / (1 + 2**-1.4)))
(1 + Y).sim(10000).plot()
Zipf(shape=1.4, n=2).plot()
