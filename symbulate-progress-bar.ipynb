# %%
from symbulate import *
import numpy as np

# %%
# Should be silent (fast)
X = RV(Normal(0, 1))
X.sim(1000)
# Out:
# Index Result
# 0     0.23233441174192024
# 1     -1.6734025165559403
# 2     -0.47560776114181086
# 3     1.7655790246064613
# 4     -0.32593839030430627
# 5     2.1012391841818903
# 6     2.965856292999521
# 7     1.6878892235345466
# 8     1.5736073900765328
# ...   ..................
# 999   0.6188983037284769

# %%
# Should show progress counter after 5 seconds
import time

P = ProbabilitySpace(lambda: (time.sleep(0.001), np.random.normal())[1])
P.sim(10000)
# Out:
# Simulating... [██████████████████████████████] 10000/10000 (100%)
# Index Result
# 0     -0.5902477441673905
# 1     -0.2782071908226615
# 2     0.12592199706487314
# 3     0.691122420943148
# 4     -0.4059560519050587
# 5     -1.0690357518473104
# 6     0.6448923195504331
# 7     -1.3085616990237987
# 8     1.4501476718533615
# ....  ...................
# 9999  -0.7665483180805597
